# %%
import numpy as np
import pandas as pd

# %%
census_data = pd.read_csv("Data/Census_data.dbf.csv", index_col = False)
cancer_data = pd.read_excel("Data/Prostate_C_2015-2019.xlsx")

# %%
print(census_data)
print(cancer_data)
# Out:
#     STATEFP20  COUNTYFP20  COUNTYNS20  GEOID20      NAME20         NAMELSAD20  \
# 0          41           9     1135847    41009    Columbia    Columbia County
# 1          41          27     1155131    41027  Hood River  Hood River County
# 2          41          25     1135852    41025      Harney      Harney County
# 3          41          41     1135856    41041     Lincoln     Lincoln County
# 4          41          33     1155133    41033   Josephine   Josephine County
# ..        ...         ...         ...      ...         ...                ...
# 70         53          47     1531928    53047    Okanogan    Okanogan County
# 71         53          63     1529225    53063     Spokane     Spokane County
# 72         53          29     1513272    53029      Island      Island County
# 73         53           9     1531341    53009     Clallam     Clallam County
# 74         53          65     1531930    53065     Stevens     Stevens County
#
# ...

# %%
census_data.head(5)
# Out:
#    STATEFP20  COUNTYFP20  COUNTYNS20  GEOID20      NAME20         NAMELSAD20  \
# 0         41           9     1135847    41009    Columbia    Columbia County
# 1         41          27     1155131    41027  Hood River  Hood River County
# 2         41          25     1135852    41025      Harney      Harney County
# 3         41          41     1135856    41041     Lincoln     Lincoln County
# 4         41          33     1155133    41033   Josephine   Josephine County
#
#    LSAD20 CLASSFP20 MTFCC20  CSAFP20  ...  GQESTIMATE  GQESTIMA_1 GQESTIMA_2  \
# 0       6        H1   G4020    440.0  ...         369         369        369
# 1       6        H1   G4020      NaN  ...         773         773        773
# 2       6        H1   G4020      NaN  ...         150         150        150
# 3       6        H1   G4020      NaN  ...         786         786        786
# 4       6        H1   G4020    366.0  ...        1520        1520       1520
#
# ...

# %%
cancer_data.head(7)
# Out:
#   WA State Cancer Registry (WSCR) Web Application  \
# 0                              Results generated:
# 1                                             NaN
# 2                                     Cancer Site
# 3                                        Prostate
# 4                                             NaN
# 5                                       Data Type
# 6                                       Incidence
#
#                         https://fortress.wa.gov/wscr Unnamed: 2 Unnamed: 3  \
# 0       May 8, 2023 6:47:06 PM Pacific Daylight Time        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                            Incidence Codes ICD-0-3        NaN        NaN
# 3  C61.9, excluding histology codes 9140, 9050-90...        NaN        NaN
# 4                                                NaN        NaN        NaN
# 5                                        Cancer Site  Geography       Year
# ...

# %%
censusvcanser_data = pd.read_csv("Pop_health.csv", index_col = False)

# %%
print(censusvcanser_data)
# Out:
#       County  Data.Type Cancer.Site       State         Year  \
# 0      Adams  Incidence    Prostate  Washington    2014-2018
# 1      Adams  Mortality    Prostate  Washington    2014-2018
# 2     Asotin  Mortality    Prostate  Washington    2014-2018
# 3     Asotin  Incidence    Prostate  Washington    2014-2018
# 4      Baker  Mortality    Prostate      Oregon  2014 - 2018
# ..       ...        ...         ...         ...          ...
# 207  Whitman  Incidence    Prostate  Washington    2014-2018
# 208   Yakima  Incidence    Prostate  Washington    2014-2018
# 209  Yamhill  Incidence    Prostate      Oregon    2014-2018
# 210  Yamhill  Mortality    Prostate      Oregon  2014 - 2018
# 211  Yamhill  Incidence    Prostate      Oregon    2014-2018
#
#      Average.Annual.Population  Average.Annual.Observations Column1   X  \
# 0                       9989.0                          6.0    85.5 NaN
# 1                       9989.0                          NaN     NaN NaN
# ...

# %%
censusvcanser_data.rename(columns = {'Column1' : 'Age_AdjRate_100'},
